# %% [markdown]
# # SVM : Support Vector Machine Algorithm

# %%
from IPython.display import Image
Image(filename='svm.JPG')

# %% [markdown]
# # Loading Data

# %%
from sklearn.datasets import load_digits
digits=load_digits()

# %%
x=digits.data

# %%
x.shape
# Out:
# (1797, 64)

# %%
x
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
y=digits.target

# %%
y.shape
# Out:
# (1797,)

# %%
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
# Standardizing the data
from sklearn.preprocessing import StandardScaler
standardized_data=StandardScaler().fit_transform(x)

# %% [markdown]
# # Test Train Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# # Linear Kernel
#
# ## Training

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='linear')
classifier.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Predictions

# %%
Y_pred=classifier.predict(X_test)

# %% [markdown]
# ## Measuring Performance
#
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
result=confusion_matrix(Y_test,Y_pred)

# %%
import seaborn as sns
sns.heatmap(result,annot=True)

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       0.91      0.98      0.94        43
#            2       0.98      1.00      0.99        44
#            3       0.98      0.96      0.97        45
#            4       0.97      1.00      0.99        38
#            5       0.98      0.98      0.98        48
#            6       1.00      0.98      0.99        52
#            7       1.00      0.98      0.99        48
#            8       0.94      0.92      0.93        48
#            9       0.96      0.94      0.95        47
#
#    micro avg       0.97      0.97      0.97       450
#    macro avg       0.97      0.97      0.97       450
# weighted avg       0.97      0.97      0.97       450

# %% [markdown]
# # Polynomial Kernel
#
# ## Training

# %%
classifier_1=SVC(kernel='poly')
classifier_1.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='poly', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Predictions

# %%
Y_pred_1=classifier_1.predict(X_test)

# %% [markdown]
# ## Measuring Performance
#
# ### Confusion matrix

# %%
result_2=confusion_matrix(Y_test,Y_pred_1)
sns.heatmap(result_2,annot=True)

# %% [markdown]
# ### Classification report

# %%
print(classification_report(Y_test,Y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       0.91      0.98      0.94        43
#            2       1.00      1.00      1.00        44
#            3       1.00      0.98      0.99        45
#            4       1.00      1.00      1.00        38
#            5       0.98      0.98      0.98        48
#            6       1.00      0.98      0.99        52
#            7       1.00      1.00      1.00        48
#            8       0.96      0.94      0.95        48
#            9       0.98      0.98      0.98        47
#
#    micro avg       0.98      0.98      0.98       450
#    macro avg       0.98      0.98      0.98       450
# weighted avg       0.98      0.98      0.98       450

# %% [markdown]
# # Gaussian Kernel
#
# ## Training

# %%
# radial basis function (RBF) : It is a general-purpose kernel used when there is no prior knowledge about the data
rbf=SVC()
rbf.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Predictions

# %%
Y_pred_rbf=rbf.predict(X_test)

# %% [markdown]
# ## Measuring Performance
#
# ### Confusion matrix

# %%
result_3=confusion_matrix(Y_test,Y_pred_rbf)
sns.heatmap(result_3,annot=True)

# %% [markdown]
# ### Classification report

# %%
print(classification_report(Y_test,Y_pred_rbf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.65      0.79        37
#            1       1.00      0.23      0.38        43
#            2       1.00      0.39      0.56        44
#            3       1.00      0.93      0.97        45
#            4       0.14      1.00      0.25        38
#            5       1.00      0.33      0.50        48
#            6       1.00      0.54      0.70        52
#            7       1.00      0.35      0.52        48
#            8       1.00      0.02      0.04        48
#            9       1.00      0.55      0.71        47
#
#    micro avg       0.49      0.49      0.49       450
#    macro avg       0.91      0.50      0.54       450
# weighted avg       0.93      0.49      0.54       450

# %% [markdown]
# # Sigmoid Kernel
#
# ## Training

# %%
classifier_2=SVC(kernel='sigmoid')
classifier_2.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='sigmoid', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Predictions

# %%
Y_pred_sig=classifier_2.predict(X_test)

# %% [markdown]
# ## Measuring Performance
#
# ### Confusion matrix

# %%
result_4=confusion_matrix(Y_test,Y_pred_sig)
sns.heatmap(result_4,annot=True)

# %% [markdown]
# ### Classification report

# %%
print(classification_report(Y_test,Y_pred_sig))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        37
#            1       0.00      0.00      0.00        43
#            2       0.00      0.00      0.00        44
#            3       0.00      0.00      0.00        45
#            4       0.08      1.00      0.16        38
#            5       0.00      0.00      0.00        48
#            6       0.00      0.00      0.00        52
#            7       0.00      0.00      0.00        48
#            8       0.00      0.00      0.00        48
#            9       0.00      0.00      0.00        47
#
#    micro avg       0.08      0.08      0.08       450
#    macro avg       0.01      0.10      0.02       450
# weighted avg       0.01      0.08      0.01       450
