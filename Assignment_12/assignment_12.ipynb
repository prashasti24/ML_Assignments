# %% [markdown]
# # NAIVE BAYES ALGORITHM

# %%
from IPython.display import Image
Image(filename='NB.JPG')

# %%
# Question 1

# To find probability of a person playing when the weather is sunny
# According to naive bayes algorithm
# p_yes_sunny = p_sunny_yes * (p_yes/p_sunny)
p_sunny_yes = 3/9
p_yes = 9/14
p_sunny = 5/14
p_yes_sunny = 3/9 * ((9/14)*(14/5))
print('Probability of a person playing when the weather is sunny is : ',p_yes_sunny)
# Out:
# Probability of a person playing when the weather is sunny is :  0.6

# %%
# Question 2

# %% [markdown]
# ## Loading Data

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
x=iris.data

# %%
x.shape
# Out:
# (150, 4)

# %%
y=iris.target

# %%
y.shape
# Out:
# (150,)

# %%
# Standardizing the data
from sklearn.preprocessing import StandardScaler
standardized_data=StandardScaler().fit_transform(x)

# %% [markdown]
# ## Test Train Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# ## Gaussian Naive Bayes
#
# ### Training

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train,Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ### Predictions

# %%
Y_pred=classifier.predict(X_test)

# %% [markdown]
# ### Measuring Performance
#
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
result=confusion_matrix(Y_test,Y_pred)

# %%
import seaborn as sns
sns.heatmap(result,annot=True)

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         9
#
#    micro avg       1.00      1.00      1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# ## Multinomial Naive Bayes
#
# ### Training

# %%
from sklearn.naive_bayes import MultinomialNB
classifier_1=MultinomialNB()
classifier_1.fit(X_train,Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ### Predictions

# %%
Y_pred_1=classifier_1.predict(X_test)

# %% [markdown]
# ### Measuring Performance
#
# #### Confusion matrix

# %%
result_2=confusion_matrix(Y_test,Y_pred_1)
sns.heatmap(result_2,annot=True)

# %% [markdown]
# #### Classification report

# %%
print(classification_report(Y_test,Y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.00      0.00      0.00        16
#            2       0.36      1.00      0.53         9
#
#    micro avg       0.58      0.58      0.58        38
#    macro avg       0.45      0.67      0.51        38
# weighted avg       0.43      0.58      0.47        38
